# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('review-Alaska_reduced_v2.csv')

# %%
df.rename(columns={'/gmap_id' : 'Business ID', '/name' : 'Name', '/rating' : 'Rating', '/text' : 'Review', '/time' : 'Time', '/user_id' : 'User ID'}, inplace = True)
df
# Out:
#                                    Business ID                     Name  \
# 0        0x56b646ed2220b77f:0xd8975e316de80952               Nicki Gore
# 1        0x56b646ed2220b77f:0xd8975e316de80952            Mitch Eichman
# 2        0x56b646ed2220b77f:0xd8975e316de80952         Johnnie Anderson
# 3        0x56b646ed2220b77f:0xd8975e316de80952                 Eric Fox
# 4        0x56b646ed2220b77f:0xd8975e316de80952            Allen Ratliff
# ...                                        ...                      ...
# 1032761  0x540c25a454fb47cf:0xf0788e2fb7ba1907                 dewa ayu
# 1032762  0x540c25a454fb47cf:0xf0788e2fb7ba1907              Kalli Kline
# 1032763  0x540c25a454fb47cf:0xf0788e2fb7ba1907           Chima Lekwauwa
# 1032764  0x540c25a454fb47cf:0xf0788e2fb7ba1907  geni Arrington- whitney
# 1032765  0x540c25a454fb47cf:0xf0788e2fb7ba1907         Ed ThePopPunkKid
#
#          Rating                                             Review  \
# ...

# %%
df.isnull().sum()
# Out:
# Business ID         0
# Name                0
# Rating              0
# Review         411557
# Time                0
# User ID             0
# dtype: int64

# %%
df.dropna()
# Out:
#                                    Business ID                    Name  \
# 0        0x56b646ed2220b77f:0xd8975e316de80952              Nicki Gore
# 1        0x56b646ed2220b77f:0xd8975e316de80952           Mitch Eichman
# 2        0x56b646ed2220b77f:0xd8975e316de80952        Johnnie Anderson
# 3        0x56b646ed2220b77f:0xd8975e316de80952                Eric Fox
# 4        0x56b646ed2220b77f:0xd8975e316de80952           Allen Ratliff
# ...                                        ...                     ...
# 1032504  0x540c25a454fb47cf:0xf0788e2fb7ba1907             J\u00f6rg S
# 1032505  0x540c25a454fb47cf:0xf0788e2fb7ba1907  Eduardo vargas duquino
# 1032506  0x540c25a454fb47cf:0xf0788e2fb7ba1907           Anatol Cazacu
# 1032507  0x540c25a454fb47cf:0xf0788e2fb7ba1907                   Vrert
# 1032508  0x540c25a454fb47cf:0xf0788e2fb7ba1907          Cayetano Oscar
#
#          Rating                                             Review  \
# ...

# %%
df.count()
# Out:
# Business ID    1032766
# Name           1032766
# Rating         1032766
# Review          621209
# Time           1032766
# User ID        1032766
# dtype: int64

# %%
df['Readable Time'] = pd.to_datetime(df['Time'], unit='ms')
df
# Out:
#                                    Business ID                     Name  \
# 0        0x56b646ed2220b77f:0xd8975e316de80952               Nicki Gore
# 1        0x56b646ed2220b77f:0xd8975e316de80952            Mitch Eichman
# 2        0x56b646ed2220b77f:0xd8975e316de80952         Johnnie Anderson
# 3        0x56b646ed2220b77f:0xd8975e316de80952                 Eric Fox
# 4        0x56b646ed2220b77f:0xd8975e316de80952            Allen Ratliff
# ...                                        ...                      ...
# 1032761  0x540c25a454fb47cf:0xf0788e2fb7ba1907                 dewa ayu
# 1032762  0x540c25a454fb47cf:0xf0788e2fb7ba1907              Kalli Kline
# 1032763  0x540c25a454fb47cf:0xf0788e2fb7ba1907           Chima Lekwauwa
# 1032764  0x540c25a454fb47cf:0xf0788e2fb7ba1907  geni Arrington- whitney
# 1032765  0x540c25a454fb47cf:0xf0788e2fb7ba1907         Ed ThePopPunkKid
#
#          Rating                                             Review  \
# ...

# %%
df.head()
# Out:
#                              Business ID              Name  Rating  \
# 0  0x56b646ed2220b77f:0xd8975e316de80952        Nicki Gore       5
# 1  0x56b646ed2220b77f:0xd8975e316de80952     Mitch Eichman       5
# 2  0x56b646ed2220b77f:0xd8975e316de80952  Johnnie Anderson       5
# 3  0x56b646ed2220b77f:0xd8975e316de80952          Eric Fox       5
# 4  0x56b646ed2220b77f:0xd8975e316de80952     Allen Ratliff       5
#
#                                               Review           Time  \
# 0  We always stay here when in Valdez for silver ...  1566331951619
# 1  This was an amazing RV camping experience with...  1503373018846
# 2  Spent the summer of 2011. Had a wonderful time...  1410062370985
# 3  My Wife and I have stayed at Bear Creek severa...  1495241580499
# 4  Great campground for the price. Nice hot unlim...  1504917982385
#
#         User ID           Readable Time
# 0  1.091298e+20 2019-08-20 20:12:31.619
# 1  1.082339e+20 2017-08-22 03:36:58.846
# ...

# %%
df['Review'] = df['Review'].astype(str)
df['totalwords'] = df['Review'].str.count('')+1
df
# Out:
#                                    Business ID                     Name  \
# 0        0x56b646ed2220b77f:0xd8975e316de80952               Nicki Gore
# 1        0x56b646ed2220b77f:0xd8975e316de80952            Mitch Eichman
# 2        0x56b646ed2220b77f:0xd8975e316de80952         Johnnie Anderson
# 3        0x56b646ed2220b77f:0xd8975e316de80952                 Eric Fox
# 4        0x56b646ed2220b77f:0xd8975e316de80952            Allen Ratliff
# ...                                        ...                      ...
# 1032761  0x540c25a454fb47cf:0xf0788e2fb7ba1907                 dewa ayu
# 1032762  0x540c25a454fb47cf:0xf0788e2fb7ba1907              Kalli Kline
# 1032763  0x540c25a454fb47cf:0xf0788e2fb7ba1907           Chima Lekwauwa
# 1032764  0x540c25a454fb47cf:0xf0788e2fb7ba1907  geni Arrington- whitney
# 1032765  0x540c25a454fb47cf:0xf0788e2fb7ba1907         Ed ThePopPunkKid
#
#          Rating                                             Review  \
# ...

# %%
df = df.drop(df[df.totalwords < 5].index)
df
# Out:
#                                    Business ID                     Name  \
# 0        0x56b646ed2220b77f:0xd8975e316de80952               Nicki Gore
# 1        0x56b646ed2220b77f:0xd8975e316de80952            Mitch Eichman
# 2        0x56b646ed2220b77f:0xd8975e316de80952         Johnnie Anderson
# 3        0x56b646ed2220b77f:0xd8975e316de80952                 Eric Fox
# 4        0x56b646ed2220b77f:0xd8975e316de80952            Allen Ratliff
# ...                                        ...                      ...
# 1032761  0x540c25a454fb47cf:0xf0788e2fb7ba1907                 dewa ayu
# 1032762  0x540c25a454fb47cf:0xf0788e2fb7ba1907              Kalli Kline
# 1032763  0x540c25a454fb47cf:0xf0788e2fb7ba1907           Chima Lekwauwa
# 1032764  0x540c25a454fb47cf:0xf0788e2fb7ba1907  geni Arrington- whitney
# 1032765  0x540c25a454fb47cf:0xf0788e2fb7ba1907         Ed ThePopPunkKid
#
#          Rating                                             Review  \
# ...

# %%
df = df.drop(df[df.totalwords < 6].index)
df
# Out:
#                                    Business ID                    Name  \
# 0        0x56b646ed2220b77f:0xd8975e316de80952              Nicki Gore
# 1        0x56b646ed2220b77f:0xd8975e316de80952           Mitch Eichman
# 2        0x56b646ed2220b77f:0xd8975e316de80952        Johnnie Anderson
# 3        0x56b646ed2220b77f:0xd8975e316de80952                Eric Fox
# 4        0x56b646ed2220b77f:0xd8975e316de80952           Allen Ratliff
# ...                                        ...                     ...
# 1032504  0x540c25a454fb47cf:0xf0788e2fb7ba1907             J\u00f6rg S
# 1032505  0x540c25a454fb47cf:0xf0788e2fb7ba1907  Eduardo vargas duquino
# 1032506  0x540c25a454fb47cf:0xf0788e2fb7ba1907           Anatol Cazacu
# 1032507  0x540c25a454fb47cf:0xf0788e2fb7ba1907                   Vrert
# 1032508  0x540c25a454fb47cf:0xf0788e2fb7ba1907          Cayetano Oscar
#
#          Rating                                             Review  \
# ...

# %%
data_dup = df.duplicated().any()
print(data_dup)
# Out:
# False

# %%
df.hist(figsize = (15,6))
plt.tight_layout
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(17,12))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap = "RdYlGn")
plt.show()

# %%
sns.countplot(x='totalwords', data=df)
plt.show()
